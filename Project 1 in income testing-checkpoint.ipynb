# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import ttest_ind,ttest_rel
from scipy import stats

# %%
data =pd.read_csv('adult.csv')
data.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 4   18          ?  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# ...

# %%
data_num=data.copy() # This syntax copy the dataframe from data to data_num data frame and make no changes in 'data' original datafame.

# %% [markdown]
# #### Check Datatype

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %% [markdown]
# ####  Data distribution

# %%
data.describe()
# Out:
#                 age  educational-num  capital-gain  capital-loss  \
# count  48842.000000     48842.000000  48842.000000  48842.000000
# mean      38.643585        10.078089   1079.067626     87.502314
# std       13.710510         2.570973   7452.019058    403.004552
# min       17.000000         1.000000      0.000000      0.000000
# 25%       28.000000         9.000000      0.000000      0.000000
# 50%       37.000000        10.000000      0.000000      0.000000
# 75%       48.000000        12.000000      0.000000      0.000000
# max       90.000000        16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# #### Categorical Data distribution

# %%
data.describe(include=['O']) #Description for Catergorical
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48842     48842               48842           48842        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race gender native-country income
# count   48842  48842          48842  48842
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %% [markdown]
# #### Null value

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# #### Check if there is any unwanted record in data

# %%
data.workclass.unique() #To check unique value of any particular series
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data.age.unique()
# Out:
# array([25, 38, 28, 44, 18, 34, 29, 63, 24, 55, 65, 36, 26, 58, 48, 43, 20,
#        37, 40, 72, 45, 22, 23, 54, 32, 46, 56, 17, 39, 52, 21, 42, 33, 30,
#        47, 41, 19, 69, 50, 31, 59, 49, 51, 27, 57, 61, 64, 79, 73, 53, 77,
#        80, 62, 35, 68, 66, 75, 60, 67, 71, 70, 90, 81, 74, 78, 82, 83, 85,
#        76, 84, 89, 88, 87, 86], dtype=int64)

# %%
data.education.unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
data['workclass'][data['workclass']=='?']
# Out:
# 4        ?
# 6        ?
# 13       ?
# 22       ?
# 35       ?
#         ..
# 48811    ?
# 48812    ?
# 48820    ?
# 48822    ?
# 48823    ?
# Name: workclass, Length: 2799, dtype: object

# %%
attrib,counts = np.unique(data['workclass'],return_counts=True)

# %%
most_freq_attrib = attrib[np.argmax(counts, axis=0)] #Axis zero means row
most_freq_attrib
# Out:
# 'Private'

# %%
data['workclass'][data['workclass']=='?']=most_freq_attrib

# %%
attrib,counts = np.unique(data['workclass'],return_counts=True)
attrib
# Out:
# array(['Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#        'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay'],
#       dtype=object)

# %% [markdown]
# # Now there is no "?". It is replaces by 'private' most frequent data

# %% [markdown]
# # Data Cleaning

# %%
attrib,counts = np.unique(data['occupation'],return_counts=True)
most_freq_attrib = attrib[np.argmax(counts, axis=0)] #Axis zero means row
data['occupation'][data['occupation']=='?']=most_freq_attrib

# %%
attrib,counts = np.unique(data['native-country'],return_counts=True)
most_freq_attrib = attrib[np.argmax(counts, axis=0)] #Axis zero means row
data['native-country'][data['native-country']=='?']=most_freq_attrib

# %%
data.workclass.unique() #checking again
# Out:
# array(['Private', 'Local-gov', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data.occupation.unique() #checking again
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv',
#        'Prof-specialty', 'Other-service', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
data['workclass'][data['workclass']=='?'] # check if there is '?' present in workclass or not?
# Out:
# Series([], Name: workclass, dtype: object)

# %%
data.isnull().sum().describe()
# Out:
# count    14.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# dtype: float64

# %% [markdown]
# #### EDA (Exploratory Data Analysis)

# %%
data['age'].hist(figsize=(6,4)) #Visualizing continuous data
plt.xlabel('Age')
plt.ylabel('No. of People')
plt.show()

# %%
data[data['age']>70].shape  #Total people count is 868 in 14 no. column
# Out:
# (868, 14)

# %% [markdown]
# #### There are 868 people who are above age 70.

# %%
data[data['age']>89].shape
# Out:
# (55, 14)

# %% [markdown]
# ### Evaluating the working hours of population

# %%
data['hours-per-week'].hist(figsize=(6,4))
plt.show()

# %% [markdown]
# ### Evaluating the Capital gain of population

# %%
data["capital-gain"].hist(figsize=(6,4))
plt.show()

# %% [markdown]
# ### Evaluating the Capital loss of population

# %%
data["capital-loss"].hist(figsize=(4,4))
plt.show()

# %% [markdown]
# ### Evaluating the Capital loss above 0 of population

# %%
data[data["capital-loss"]>0].shape
# Out:
# (2282, 14)

# %% [markdown]
# ### Evaluating the Relation between Capital loss  and capital gain of population

# %%
sns.relplot(x='capital-gain',y='capital-loss',data=data)  #Relation plot between capital-loss Vs capital-gain
plt.xlabel('capital gain')
plt.ylabel('capital loss')
plt.show()

# %% [markdown]
# ### Evaluating the  categorical Relation in bar chart

# %% [markdown]
# ##### Working sector  vs population count

# %%
plt.figure(figsize=(15,5))
total = float(len(data['income']))

ax=sns.countplot(x="workclass",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="center")
    
   
    
plt.show()

# %%
plt.figure(figsize=(20,10))
total = float(len(data['income']))

ax=sns.countplot(x="education",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="right")

    plt.title('Count plot of Income Vs Education')
plt.show()

# %%
plt.figure(figsize=(20,10))
total = float(len(data['income']))

ax=sns.countplot(x="marital-status",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="right")

    plt.title('Count plot of Marrital Status')
plt.show()

# %%
plt.figure(figsize=(20,10))
total = float(len(data['income']))

ax=sns.countplot(x="occupation",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="center")

    plt.title('Count plot of Occupation')
plt.show()

# %%
plt.figure(figsize=(20,10))
total = float(len(data['income']))

ax=sns.countplot(x="relationship",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="right")

    plt.title('Count plot of Relationship')
plt.show()

# %%
plt.figure(figsize=(10,5))
total = float(len(data['income']))

ax=sns.countplot(x="race",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="right")

    plt.title('Count plot of Race')
plt.show()

# %%
plt.figure(figsize=(10,5))
total = float(len(data['income']))

ax=sns.countplot(x="income",data=data)

#code to show data level in bar chart

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.0,
    height +3,'{:1.2f}'.format((height/total)*100),ha="right")

    plt.title('Count plot of Income')
plt.show()

# %% [markdown]
# # Bivarient Analysis

# %%
data.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 4   18    Private  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4     Prof-specialty    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# ...

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(x='income', y = 'age',data=data)
plt.show()

# %%
data['income']=data['income'].map({'<=50K':0, '>50K':1, '<=50K. ':0, '>50K. ':1})
data.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 4   18    Private  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4     Prof-specialty    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income
# 0              40  United-States       0
# ...

# %%
data[['income','age']].groupby(['income'],as_index=False).median().sort_values(by='age',ascending=False)
# Out:
#    income   age
# 1       1  43.0
# 0       0  34.0

# %%
import random
datatest = data[(np.abs(stats.zscore(data['age']))<3)]
income_1=datatest[datatest['income']==1]['age']
income_0=datatest[datatest['income']==0]['age']

income_0 = income_0.values.tolist()
income_0=random.sample(income_0,100)
income_1 = income_1.values.tolist()
income_1=random.sample(income_1,100)

# %%
from scipy.stats import ttest_ind
ttest,pval=ttest_ind(income_1,income_0,equal_var=False)
print("ttest",ttest)
print('p value',pval)

if pval<0.05:
    print ('we reject null hypothesis hence dependency or have relation')
else:
    print ('we accept null hypothesis hence independency')
# Out:
# ttest 4.8541575430096415
# p value 2.7630863975612033e-06
# we reject null hypothesis hence dependency or have relation

# %% [markdown]
# # Testing hypothesis on Income according to Hour Per Week

# %%
data.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 4   18    Private  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4     Prof-specialty    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income
# 0              40  United-States       0
# ...

# %%
fig=plt.figure(figsize=(10,5))
sns.boxplot(x='income',y='hours-per-week',data=data)
plt.show()

# %% [markdown]
# #### This above chart says,
# #### Income having <50K works around 35 hrs-40 hrs per week
# #### Income having >=50K works around 40 hrs-50 hrs per week

# %%
data = data[(np.abs(stats.zscore(data['hours-per-week']))<3)]

income_1=datatest[datatest['income']==1]['hours-per-week']
income_0=datatest[datatest['income']==0]['hours-per-week']

income_0 = income_0.values.tolist()
income_0=random.sample(income_0,100)
income_1 = income_1.values.tolist()
income_1=random.sample(income_1,100)


from scipy.stats import ttest_ind
ttest,pval=ttest_ind(income_1,income_0,equal_var=False)
print("ttest:- ",ttest)
print('p value:- ',pval)

if pval<0.05:
    print ('we reject null hypothesis')
else:
    print ('we accept null hypothesis')
# Out:
# ttest:-  3.249469257786785
# p value:-  0.0013587124157568545
# we reject null hypothesis

# %% [markdown]
# # Testing hypothesis on Income according to Capital gain

# %%
fig=plt.figure(figsize=(10,7))
sns.boxplot(x='income',y='capital-gain',data=data)
plt.show()

# %%
data = data[(np.abs(stats.zscore(data['capital-gain']))<3)]

income_1=datatest[datatest['income']==1]['capital-gain']
income_0=datatest[datatest['income']==0]['capital-gain']

income_0 = income_0.values.tolist()
income_0=random.sample(income_0,100)
income_1 = income_1.values.tolist()
income_1=random.sample(income_1,100)


from scipy.stats import ttest_ind
ttest,pval=ttest_ind(income_1,income_0,equal_var=False)
print("ttest:- ",ttest)
print('p value:- ',pval)

if pval<0.05:
    print ('we reject null hypothesis')
else:
    print ('we accept null hypothesis')
# Out:
# ttest:-  2.9154983396446905
# p value:-  0.004392348279476326
# we reject null hypothesis

# %%
fig=plt.figure(figsize=(10,7))
sns.boxplot(x='income',y='capital-loss',data=data)
plt.show()

data = data[(np.abs(stats.zscore(data['capital-loss']))<3)]

income_1=datatest[datatest['income']==1]['capital-loss']
income_0=datatest[datatest['income']==0]['capital-loss']

income_0 = income_0.values.tolist()
income_0=random.sample(income_0,100)
income_1 = income_1.values.tolist()
income_1=random.sample(income_1,100)


from scipy.stats import ttest_ind
ttest,pval=ttest_ind(income_1,income_0,equal_var=False)
print("ttest:- ",ttest)
print('p value:- ',pval)

if pval<0.05:
    print ('we reject null hypothesis')
else:
    print ('we accept null hypothesis')
# Out:
# ttest:-  0.958166596963986
# p value:-  0.3392407501163476
# we accept null hypothesis

# %% [markdown]
# # categorical Relationship

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='workclass',hue='income', data=data)
plt.title('Analysis Between Workplace and Income', fontweight='bold')
plt.show()

# %%
c_t=pd.crosstab(data['workclass'].sample(frac=0.004,replace=True, random_state=1),data['income'].sample(frac=0.004,
    replace=True,random_state=1),margins=False)
c_t
# Out:
# income              0   1
# workclass
# Federal-gov         3   2
# Local-gov           5   4
# Private           108  30
# Self-emp-inc        3   2
# Self-emp-not-inc   11   1
# State-gov          12   2

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=5
# p_val 0.28463718785605835
# accept

# %%
plt.figure(figsize=(15,9))
ax=sns.countplot(x='education',hue='income', data=data)
plt.title('Analysis Between Education and Income', fontweight='bold')
plt.show()

# %%
c_t=pd.crosstab(data['education'].sample(frac=0.004,replace=True, random_state=1),data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income         0   1
# education
# 10th           5   0
# 11th          15   0
# 12th           4   0
# 5th-6th        2   0
# 7th-8th        4   0
# 9th            2   0
# Assoc-acdm     6   2
# Assoc-voc      8   1
# Bachelors     20  12
# Doctorate      1   2
# HS-grad       51  10
# Masters        2   5
# Preschool      1   0
# Prof-school    0   2
# Some-college  21   7

# %%
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=14
# p_val 0.001127474949221262
# reject

# %%
plt.figure(figsize=(15,9))
ax=sns.countplot(x='marital-status',hue='income', data=data)
plt.title('Analysis Between Martal-stauts and Income', fontweight='bold')
plt.show()
c_t=pd.crosstab(data['marital-status'].sample(frac=0.004,replace=True, random_state=1),data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income                  0   1
# marital-status
# Divorced               23   2
# Married-civ-spouse     51  36
# Married-spouse-absent   1   2
# Never-married          56   1
# Separated               6   0
# Widowed                 5   0

# %%
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=5
# p_val 7.29811642446377e-08
# reject

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(x='occupation',hue='income', data=data)
plt.title('Analysis Between Occupation and Income', fontweight='bold')
plt.show()
c_t=pd.crosstab(data['occupation'].sample(frac=0.004,replace=True, random_state=1),
    data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income              0   1
# occupation
# Adm-clerical       18   2
# Craft-repair       19   4
# Exec-managerial    16   7
# Farming-fishing     8   2
# Handlers-cleaners   3   2
# Machine-op-inspct  10   0
# Other-service      17   0
# Priv-house-serv     1   0
# Prof-specialty     17  10
# Protective-serv     0   3
# Sales              22   7
# Tech-support        6   3
# Transport-moving    5   1

# %%
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=12
# p_val 0.009229153249860417
# reject

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(x='relationship',hue='income', data=data)
plt.title('Analysis Between Relationship and Income', fontweight='bold')
plt.show()
c_t=pd.crosstab(data['relationship'].sample(frac=0.004,replace=True, random_state=1),
                data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income           0   1
# relationship
# Husband         42  33
# Not-in-family   38   5
# Other-relative   4   0
# Own-child       28   1
# Unmarried       23   0
# Wife             7   2

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(x='race',hue='income', data=data)
plt.title('Analysis Between Race and Income', fontweight='bold')
plt.show()
c_t=pd.crosstab(data['race'].sample(frac=0.004,replace=True, random_state=1),
                data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income                0   1
# race
# Amer-Indian-Eskimo    2   0
# Asian-Pac-Islander    6   3
# Black                17   1
# White               117  37

# %%
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=3
# p_val 0.22436825335587923
# accept

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(x='gender',hue='income', data=data)
plt.show()
c_t=pd.crosstab(data['gender'].sample(frac=0.004,replace=True, random_state=1),
                data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
# Out:
# income   0   1
# gender
# Female  68   2
# Male    74  39

# %%
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=1
# p_val 1.5157174664673413e-06
# reject

# %%
c_t=pd.crosstab(data['native-country'].sample(frac=0.004,replace=True, random_state=1),data['income'].sample(frac=0.004,replace=True,random_state=1),margins=False)
c_t
stat, p , dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_val',p)

if p<0.05:
    print('reject')
    
else:
    print('accept')
# Out:
# dof=13
# p_val 0.16891991488397198
# accept

# %% [markdown]
# # Some Multivarient Relationship

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data_num.corr(),annot=True,linewidths=.5, cmap='Reds')
plt.title('Heatmap showing correaltionship between numerical data', fontweight='bold')
plt.show()

# %% [markdown]
# # Multivarient Analysis

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='income', y='hours-per-week',hue='gender',data=data)
plt.title('Multivarient Analysis Between Work Hour, Age, Gender', fontweight='bold')
plt.show()

# %% [markdown]
# # Multivarient Analysis between Income, Age, Gender

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='income', y='age',hue='gender',data=data)
plt.title('Multivarient Analysis Between Income, Age, Gender', fontweight='bold')
plt.show()

# %%
cols = ['workload', 'occupation']
cat_col=data.dtypes[data.dtypes=='object']
for col in cat_col.index:
    if col in cols:
        print(f'=================={col}============')
        print(data_num[data_num['hours-per-week']==99][col].value_counts())
    else:
        continue
# Out:
# ==================occupation============
# Prof-specialty       25
# Farming-fishing      20
# Transport-moving     19
# Exec-managerial      18
# Other-service        15
# ?                    11
# Craft-repair         10
# Sales                 6
# Protective-serv       4
# Priv-house-serv       4
# Adm-clerical          2
# Tech-support          2
# Handlers-cleaners     1
# Name: occupation, dtype: int64

# %%
cols = ['workclass', 'occupation']
cat_col=data.dtypes[data.dtypes=='object']
for col in cat_col.index:
    if col in cols:
        print(f'=================={col}============')
        print(data_num[data_num['age']==90][col].value_counts())
    else:
        continue
# Out:
# ==================workclass============
# Private             35
# ?                    8
# Self-emp-not-inc     5
# Local-gov            5
# Federal-gov          2
# Name: workclass, dtype: int64
# ==================occupation============
# Exec-managerial      9
# Prof-specialty       8
# ?                    8
# Other-service        7
# Adm-clerical         6
# Craft-repair         5
# Sales                4
# Machine-op-inspct    3
# Transport-moving     2
# Handlers-cleaners    1
# Farming-fishing      1
# Protective-serv      1
# Name: occupation, dtype: int64

# %% [markdown]
# # Making new variable (capital_change)

# %% [markdown]
# ### i. Summary statistics

# %%
data['capital_change']=data['capital-gain']-data['capital-loss']

# %%
data.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 4   18    Private  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4     Prof-specialty    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income  capital_change
# ...

# %% [markdown]
# ### ii. Distribution

# %%
data['capital_change'].hist(figsize=(12,5))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### ii. Distribution

# %%
income_1=data[data['income']==1]['capital_change']
income_0=data[data['income']==0]['capital_change']

data=data[(np.abs(stats.zscore(data['capital_change']))<3)]

income_0=income_0.values.tolist()
income_0=random.sample(income_0,100)
income_1=income_1.values.tolist()
income_1=random.sample(income_1,100)

ttest,pval=ttest_ind(income_1,income_0,equal_var=0)
print('ttest',ttest)
print('p-value',pval)

if pval<0.05:
    print('we reject null bypothesis')
else:
    print('we accept null bypothesis')
# Out:
# ttest 3.050874541912793
# p-value 0.0028632674026115874
# we reject null bypothesis
